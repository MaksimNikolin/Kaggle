# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# **Load Train and Validation datasets**

# %%
train_dataset_path = 'C:/Users/maxni/OneDrive/Desktop/Programming/Datasets/dataset_images_multiclass/seg_train'
val_dataset_path = 'C:/Users/maxni/OneDrive/Desktop/Programming/Datasets/dataset_images_multiclass/seg_test'

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                    target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                    batch_size=BATCH_SIZE,
                                                    class_mode='categorical',
                                                    shuffle=True)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
val_datagen = ImageDataGenerator(rescale=1.0/255)

val_generator = val_datagen.flow_from_directory(val_dataset_path,
                                                target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                batch_size=BATCH_SIZE,
                                                class_mode='categorical',
                                                shuffle=True)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : buildings
# 1 : forest
# 2 : glacier
# 3 : mountain
# 4 : sea
# 5 : street

# %% [markdown]
# **Plotting sample training images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# **Create and train CNN model**

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=6, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 128)     9728
#
#  activation (Activation)     (None, 146, 146, 128)     0
#
#  max_pooling2d (MaxPooling2D  (None, 73, 73, 128)      0
#  )
#
#  batch_normalization (BatchN  (None, 73, 73, 128)      512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 71, 71, 64)        73792
#
#  activation_1 (Activation)   (None, 71, 71, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 35, 35, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 35, 35, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 33, 33, 32)        18464
#
#  activation_2 (Activation)   (None, 33, 33, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 2,201,830
# Trainable params: 2,201,382
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
cnn_model.compile(optimizer=Adam(learning_rate=0.001), loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=val_generator,
                        verbose=2, callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 439/439 - 729s - loss: 2.0128 - accuracy: 0.4860 - val_loss: 1.2952 - val_accuracy: 0.5197 - lr: 0.0010 - 729s/epoch - 2s/step
# Epoch 2/50
# 439/439 - 625s - loss: 1.0777 - accuracy: 0.6048 - val_loss: 0.9941 - val_accuracy: 0.6223 - lr: 0.0010 - 625s/epoch - 1s/step
# Epoch 3/50
# 439/439 - 615s - loss: 0.9265 - accuracy: 0.6583 - val_loss: 1.0099 - val_accuracy: 0.6513 - lr: 0.0010 - 615s/epoch - 1s/step
# Epoch 4/50
# 439/439 - 612s - loss: 0.8484 - accuracy: 0.6880 - val_loss: 1.0037 - val_accuracy: 0.6343 - lr: 0.0010 - 612s/epoch - 1s/step
# Epoch 5/50
# 439/439 - 613s - loss: 0.8056 - accuracy: 0.7143 - val_loss: 0.8552 - val_accuracy: 0.6627 - lr: 0.0010 - 613s/epoch - 1s/step
# Epoch 6/50
# 439/439 - 601s - loss: 0.7602 - accuracy: 0.7279 - val_loss: 1.3696 - val_accuracy: 0.5390 - lr: 0.0010 - 601s/epoch - 1s/step
# Epoch 7/50
# 439/439 - 594s - loss: 0.7342 - accuracy: 0.7413 - val_loss: 0.7082 - val_accuracy: 0.7233 - lr: 0.0010 - 594s/epoch - 1s/step
# Epoch 8/50
# 439/439 - 594s - loss: 0.6871 - accuracy: 0.7558 - val_loss: 0.9028 - val_accuracy: 0.6870 - lr: 0.0010 - 594s/epoch - 1s/step
# Epoch 9/50
# 439/439 - 595s - loss: 0.6691 - accuracy: 0.7615 - val_loss: 0.6224 - val_accuracy: 0.7917 - lr: 0.0010 - 595s/epoch - 1s/step
# Epoch 10/50
# 439/439 - 598s - loss: 0.6342 - accuracy: 0.7770 - val_loss: 0.8651 - val_accuracy: 0.7143 - lr: 0.0010 - 598s/epoch - 1s/step
# Epoch 11/50
# 439/439 - 4386s - loss: 0.6175 - accuracy: 0.7858 - val_loss: 1.4997 - val_accuracy: 0.6380 - lr: 0.0010 - 4386s/epoch - 10s/step
# Epoch 12/50
# 439/439 - 603s - loss: 0.6093 - accuracy: 0.7886 - val_loss: 0.6248 - val_accuracy: 0.7917 - lr: 0.0010 - 603s/epoch - 1s/step
# Epoch 13/50
# 439/439 - 597s - loss: 0.5829 - accuracy: 0.7983 - val_loss: 0.5712 - val_accuracy: 0.7900 - lr: 0.0010 - 597s/epoch - 1s/step
# Epoch 14/50
# 439/439 - 614s - loss: 0.5726 - accuracy: 0.8054 - val_loss: 0.5796 - val_accuracy: 0.8070 - lr: 0.0010 - 614s/epoch - 1s/step
# Epoch 15/50
# 439/439 - 625s - loss: 0.5671 - accuracy: 0.8033 - val_loss: 0.6283 - val_accuracy: 0.8007 - lr: 0.0010 - 625s/epoch - 1s/step
# Epoch 16/50
# 439/439 - 640s - loss: 0.5477 - accuracy: 0.8153 - val_loss: 0.4852 - val_accuracy: 0.8423 - lr: 0.0010 - 640s/epoch - 1s/step
# Epoch 17/50
# 439/439 - 608s - loss: 0.5514 - accuracy: 0.8140 - val_loss: 0.8556 - val_accuracy: 0.7350 - lr: 0.0010 - 608s/epoch - 1s/step
# Epoch 18/50
# 439/439 - 597s - loss: 0.5361 - accuracy: 0.8143 - val_loss: 0.4955 - val_accuracy: 0.8193 - lr: 0.0010 - 597s/epoch - 1s/step
# Epoch 19/50
# 439/439 - 594s - loss: 0.5153 - accuracy: 0.8236 - val_loss: 0.5101 - val_accuracy: 0.8303 - lr: 0.0010 - 594s/epoch - 1s/step
# Epoch 20/50
# 439/439 - 599s - loss: 0.5183 - accuracy: 0.8218 - val_loss: 0.5676 - val_accuracy: 0.7923 - lr: 0.0010 - 599s/epoch - 1s/step
# Epoch 21/50
# 439/439 - 595s - loss: 0.5202 - accuracy: 0.8222 - val_loss: 0.7213 - val_accuracy: 0.7717 - lr: 0.0010 - 595s/epoch - 1s/step
# Epoch 22/50
# 439/439 - 600s - loss: 0.4454 - accuracy: 0.8462 - val_loss: 0.3527 - val_accuracy: 0.8863 - lr: 3.1623e-04 - 600s/epoch - 1s/step
# Epoch 23/50
# 439/439 - 630s - loss: 0.4230 - accuracy: 0.8570 - val_loss: 0.3609 - val_accuracy: 0.8780 - lr: 3.1623e-04 - 630s/epoch - 1s/step
# Epoch 24/50
# 439/439 - 610s - loss: 0.4254 - accuracy: 0.8546 - val_loss: 0.3544 - val_accuracy: 0.8810 - lr: 3.1623e-04 - 610s/epoch - 1s/step
# Epoch 25/50
# 439/439 - 594s - loss: 0.4103 - accuracy: 0.8607 - val_loss: 0.3578 - val_accuracy: 0.8843 - lr: 3.1623e-04 - 594s/epoch - 1s/step
# Epoch 26/50
# 439/439 - 658s - loss: 0.4003 - accuracy: 0.8628 - val_loss: 0.3663 - val_accuracy: 0.8833 - lr: 3.1623e-04 - 658s/epoch - 1s/step
# Epoch 27/50
# 439/439 - 695s - loss: 0.4063 - accuracy: 0.8618 - val_loss: 0.3486 - val_accuracy: 0.8853 - lr: 3.1623e-04 - 695s/epoch - 2s/step
# Epoch 28/50
# 439/439 - 687s - loss: 0.3956 - accuracy: 0.8650 - val_loss: 0.3862 - val_accuracy: 0.8740 - lr: 3.1623e-04 - 687s/epoch - 2s/step
# Epoch 29/50
# 439/439 - 707s - loss: 0.3886 - accuracy: 0.8687 - val_loss: 0.3382 - val_accuracy: 0.8920 - lr: 3.1623e-04 - 707s/epoch - 2s/step
# Epoch 30/50
# 439/439 - 642s - loss: 0.3905 - accuracy: 0.8699 - val_loss: 0.3879 - val_accuracy: 0.8713 - lr: 3.1623e-04 - 642s/epoch - 1s/step
# Epoch 31/50
# 439/439 - 647s - loss: 0.3713 - accuracy: 0.8749 - val_loss: 0.4526 - val_accuracy: 0.8633 - lr: 3.1623e-04 - 647s/epoch - 1s/step
# Epoch 32/50
# 439/439 - 629s - loss: 0.3763 - accuracy: 0.8697 - val_loss: 0.3686 - val_accuracy: 0.8790 - lr: 3.1623e-04 - 629s/epoch - 1s/step
# Epoch 33/50
# 439/439 - 596s - loss: 0.3839 - accuracy: 0.8688 - val_loss: 0.4591 - val_accuracy: 0.8667 - lr: 3.1623e-04 - 596s/epoch - 1s/step
# Epoch 34/50
# 439/439 - 595s - loss: 0.3851 - accuracy: 0.8725 - val_loss: 0.9694 - val_accuracy: 0.7170 - lr: 3.1623e-04 - 595s/epoch - 1s/step
# Epoch 35/50
# 439/439 - 597s - loss: 0.3615 - accuracy: 0.8787 - val_loss: 0.3193 - val_accuracy: 0.8960 - lr: 1.0000e-04 - 597s/epoch - 1s/step
# Epoch 36/50
# 439/439 - 663s - loss: 0.3454 - accuracy: 0.8863 - val_loss: 0.3683 - val_accuracy: 0.8770 - lr: 1.0000e-04 - 663s/epoch - 2s/step
# Epoch 37/50
# 439/439 - 583s - loss: 0.3454 - accuracy: 0.8849 - val_loss: 0.3274 - val_accuracy: 0.8967 - lr: 1.0000e-04 - 583s/epoch - 1s/step
# Epoch 38/50
# 439/439 - 591s - loss: 0.3460 - accuracy: 0.8838 - val_loss: 0.3166 - val_accuracy: 0.8933 - lr: 1.0000e-04 - 591s/epoch - 1s/step
# Epoch 39/50
# 439/439 - 596s - loss: 0.3435 - accuracy: 0.8854 - val_loss: 0.3166 - val_accuracy: 0.8940 - lr: 1.0000e-04 - 596s/epoch - 1s/step
# Epoch 40/50
# 439/439 - 595s - loss: 0.3368 - accuracy: 0.8871 - val_loss: 0.3275 - val_accuracy: 0.8917 - lr: 1.0000e-04 - 595s/epoch - 1s/step
# Epoch 41/50
# 439/439 - 598s - loss: 0.3420 - accuracy: 0.8861 - val_loss: 0.3405 - val_accuracy: 0.8927 - lr: 1.0000e-04 - 598s/epoch - 1s/step
# Epoch 42/50
# 439/439 - 594s - loss: 0.3385 - accuracy: 0.8825 - val_loss: 0.3251 - val_accuracy: 0.8970 - lr: 1.0000e-04 - 594s/epoch - 1s/step
# Epoch 43/50
# 439/439 - 599s - loss: 0.3372 - accuracy: 0.8876 - val_loss: 0.3450 - val_accuracy: 0.8923 - lr: 1.0000e-04 - 599s/epoch - 1s/step
# Epoch 44/50
# 439/439 - 600s - loss: 0.3304 - accuracy: 0.8876 - val_loss: 0.3178 - val_accuracy: 0.8977 - lr: 3.1623e-05 - 600s/epoch - 1s/step
# Epoch 45/50
# 439/439 - 599s - loss: 0.3223 - accuracy: 0.8891 - val_loss: 0.3136 - val_accuracy: 0.8983 - lr: 3.1623e-05 - 599s/epoch - 1s/step
# Epoch 46/50
# 439/439 - 599s - loss: 0.3236 - accuracy: 0.8893 - val_loss: 0.3233 - val_accuracy: 0.8947 - lr: 3.1623e-05 - 599s/epoch - 1s/step
# Epoch 47/50
# 439/439 - 599s - loss: 0.3275 - accuracy: 0.8898 - val_loss: 0.3192 - val_accuracy: 0.8970 - lr: 3.1623e-05 - 599s/epoch - 1s/step
# Epoch 48/50
# 439/439 - 599s - loss: 0.3197 - accuracy: 0.8938 - val_loss: 0.3373 - val_accuracy: 0.8907 - lr: 3.1623e-05 - 599s/epoch - 1s/step
# Epoch 49/50
# 439/439 - 601s - loss: 0.3233 - accuracy: 0.8911 - val_loss: 0.3199 - val_accuracy: 0.8957 - lr: 3.1623e-05 - 601s/epoch - 1s/step
# Epoch 50/50
# 439/439 - 599s - loss: 0.3300 - accuracy: 0.8869 - val_loss: 0.3334 - val_accuracy: 0.8940 - lr: 3.1623e-05 - 599s/epoch - 1s/step

# %% [markdown]
# **Plotting the Model Metrics**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Testing the Model on Test dataset**

# %%
test_dataset_path = 'C:/Users/maxni/OneDrive/Desktop/Programming/Datasets/dataset_images_multiclass/seg_test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset_path,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 6 classes.

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 94/94 [==============================] - 23s 236ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 94/94 [==============================] - 23s 240ms/step - loss: 0.3334 - accuracy: 0.8940

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.33337950706481934
# Test Accuracy: 0.8939999938011169

# %% [markdown]
# **Plotting the Classification Metrics**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(6, 6)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.86      0.90      0.88       437
#       forest       0.97      0.98      0.98       474
#      glacier       0.86      0.84      0.85       553
#     mountain       0.86      0.80      0.83       525
#          sea       0.90      0.95      0.92       510
#       street       0.92      0.91      0.91       501
#
#     accuracy                           0.89      3000
#    macro avg       0.89      0.90      0.90      3000
# weighted avg       0.89      0.89      0.89      3000

# %% [markdown]
# **Wrong Predictions**

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset_path, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4456\670646159.py in <module>
#      10         predicted_label = labels[predicted_index]
#      11         ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
# ---> 12         img_path = os.path.join(test_dataset_зфер, test_img[idx])
#      13         img = cv2.imread(img_path)
#      14         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#
# NameError: name 'test_dataset_зфер' is not defined
